# %%
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL

# %sql ibm_db_sa://
# Out:
# 'Connected: bls44444@BLUDB'

# %% [markdown]
# ### Checking table

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
#%sql select * from syscat.tables where tabschema = 'BLS44444'
# %sql select * from syscat.tables where tabname = 'SCHOOLS'
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('BLS44444', 'SCHOOLS', 'BLS44444', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2022, 4, 24, 16, 56, 11, 958401), datetime.datetime(2022, 4, 24, 16, 56, 11, 958401), datetime.datetime(2022, 4, 24, 16, 56, 11, 958401), datetime.datetime(2022, 4, 24, 17, 0, 38, 40308), 78, 17, 4603, 566, 15, 0, 16, -1, -1, -1, 0, 'BLS44444SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2022, 4, 24, 16, 56, 11, 958401), 0, ' ', None, None, 'N', 'BLS44444', ' ', ' ', ' ', datetime.date(2022, 4, 26), ' ', 'N', 'R', 'N', -1.0, None)]

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### How many columns does "SCHOOLS" table have?

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table
# %sql select count(*) from syscat.columns where tabname = 'SCHOOLS'
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [(78,)]

# %% [markdown]
# #### Retrieving the Column_names, Column type, and Column lenghts

# %%
# type in your query to retrieve all column names in the SCHOOLS table along with their datatypes and length
# %sql select COLNAME, TYPENAME, LENGTH from syscat.columns where tabname = 'SCHOOLS'
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('SCHOOL_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 64),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('STREET_ADDRESS', 'VARCHAR', 29),
#  ('CITY', 'VARCHAR', 7),
#  ('STATE', 'VARCHAR', 2),
#  ('ZIP_CODE', 'INTEGER', 4),
#  ('PHONE_NUMBER', 'VARCHAR', 14),
#  ('LINK', 'VARCHAR', 78),
#  ('NETWORK_MANAGER', 'VARCHAR', 40),
#  ('COLLABORATIVE_NAME', 'VARCHAR', 34),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR', 3),
#  ('TRACK_SCHEDULE', 'VARCHAR', 12),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR', 16),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('SAFETY_ICON', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('FAMILY_INVOLVEMENT_ICON', 'VARCHAR', 11),
#  ('FAMILY_INVOLVEMENT_SCORE', 'VARCHAR', 3),
#  ('ENVIRONMENT_ICON', 'VARCHAR', 11),
# ...

# %% [markdown]
# #### Q1: How many Elementary Schools are in the dataset?

# %%
# %sql select count(*) from schools where "Elementary, Middle, or High School" = 'ES'
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [(462,)]

# %% [markdown]
# #### Q2: What is the highest Safety Score?

# %%
# %sql select max(safety_score) from schools
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [(99,)]

# %% [markdown]
# #### Q3: Which schools have highest Safety Score?

# %%
# %sql select name_of_school,safety_score from schools where safety_score = (select max(safety_score) from schools)
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('Abraham Lincoln Elementary School', 99),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('Augustus H Burley Elementary School', 99),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('Ellen Mitchell Elementary School', 99),
#  ('James E McDade Elementary Classical School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('LaSalle Elementary Language Academy', 99),
#  ('Mary E Courtenay Elementary Language Arts Center', 99),
#  ('Northside College Preparatory High School', 99),
#  ('Northside Learning Center High School', 99),
#  ('Norwood Park Elementary School', 99),
#  ('Oriole Park Elementary School', 99),
#  ('Sauganash Elementary School', 99),
#  ('Stephen Decatur Classical Elementary School', 99),
# ...

# %% [markdown]
# #### Q4: What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %sql select Name_of_school, average_student_attendance from schools \
        order by Average_Student_Attendance desc nulls  last limit 10
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# #### Q5: Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %sql select Name_of_school, average_student_attendance from schools \
        order by Average_Student_Attendance nulls  last limit 5
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# #### Q6: Remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %sql select Name_of_school, replace(average_student_attendance,'%', '') as average from schools \
        order by Average_Student_Attendance nulls  last limit 5
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %% [markdown]
# #### Q7: Which Schools have Average Student Attendance lower than 70%?

# %%
#%sql select name_of_school from schools where decimal(replace(average_student_attendance,'%', '')) < 70

# %sql select name_of_school from schools where cast(replace(average_student_attendance,'%', '') as double) < 70
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('Barbara Vick Early Childhood & Family Center',),
#  ('Chicago Vocational Career Academy High School',),
#  ('Dyett High School',),
#  ('Manley Career Academy High School',),
#  ('Orr Academy High School',),
#  ('Richard T Crane Technical Preparatory High School',),
#  ('Roberto Clemente Community Academy High School',),
#  ('Wendell Phillips Academy High School',)]

# %% [markdown]
# #### Q8 Get the total College Enrollment for each Community Area

# %%
# %sql select community_area_name, sum(college_enrollment) total_enrollment from schools \
        group by community_area_name  \
        order by 2 desc
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('SOUTH LAWNDALE', 14793),
#  ('BELMONT CRAGIN', 14386),
#  ('AUSTIN', 10933),
#  ('GAGE PARK', 9915),
#  ('BRIGHTON PARK', 9647),
#  ('WEST TOWN', 9429),
#  ('HUMBOLDT PARK', 8620),
#  ('WEST RIDGE', 8197),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('IRVING PARK', 7764),
#  ('NORTH CENTER', 7541),
#  ('LOGAN SQUARE', 7351),
#  ('LOWER WEST SIDE', 7257),
#  ('CHICAGO LAWN', 7086),
#  ('LAKE VIEW', 7055),
#  ('ROSELAND', 7020),
#  ('PORTAGE PARK', 6954),
#  ('ALBANY PARK', 6864),
#  ('ENGLEWOOD', 6832),
#  ('ASHBURN', 6483),
#  ('NORWOOD PARK', 6469),
#  ('WEST ENGLEWOOD', 5946),
#  ('LINCOLN PARK', 5615),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('NORTH LAWNDALE', 5146),
#  ('CHATHAM', 5042),
#  ('ARCHER HEIGHTS', 4823),
#  ('DOUGLAS', 4670),
#  ('EDGEWATER', 4600),
#  ('DUNNING', 4568),
#  ('GARFIELD RIDGE', 4552),
# ...

# %% [markdown]
# #### Q9: Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %%
# %sql select community_area_name,college_enrollment from schools \
     order by 2  limit 5
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('NEAR WEST SIDE', 21),
#  ('CALUMET HEIGHTS', 26),
#  ('ENGLEWOOD', 44),
#  ('NORTH LAWNDALE', 48),
#  ('NORTH LAWNDALE', 83)]

# %% [markdown]
# #### Q10: List 5 schools with lowest safety score.

# %%
# %sql select community_area_name,safety_score from schools \
     order by 2 fetch first 5 rows only
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [('WASHINGTON PARK', 1),
#  ('WEST ENGLEWOOD', 5),
#  ('WEST GARFIELD PARK', 6),
#  ('AUBURN GRESHAM', 11),
#  ('GREATER GRAND CROSSING', 13)]

# %% [markdown]
# #### Q11: Get the hardship index for the community area which has College Enrollment of 4368

# %%
# %sql select hardship_index from chicago_socioeconomic_data CD, schools CPS \
     where CD.ca = CPS.community_area_number \
     and college_enrollment = 4368
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [(6.0,)]

# %% [markdown]
# #### Q12: Get the hardship index for the community area which has the school with the  highest enrollment.

# %%
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
   where ca in \
   ( select community_area_number from schools order by college_enrollment desc limit 1 )
# Out:
#  * ibm_db_sa://bls44444:***@19af6446-6171-4641-8aba-9dcff8e1b6ff.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:30699/BLUDB
# Done.
# [(5.0, 'North Center', 6.0)]
